# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
def generate_data(n=1000, d=10):
    X = np.random.randn(n, d)
    true_w = np.random.randn(d)
    logits = X @ true_w
    y = (logits > 0).astype(int)
    return X, y

X, y = generate_data()
n, d = X.shape

# %%
def sigmoid(z):
    z = np.clip(z, -50, 50)
    return 1 / (1 + np.exp(-z))

def grad_i(w, x_i, y_i):
    p = sigmoid(x_i @ w)
    return (p - y_i) * x_i

# %%
def full_gradient(w, X, y):
    n = X.shape[0]
    grad = np.zeros_like(w)
    for i in range(n):
        z = np.clip(X[i] @ w, -50, 50)
        p = 1 / (1 + np.exp(-z))
        grad += (p - y[i]) * X[i]
    return grad / n

# %%
def adagrad(X, y, lr=0.1, epochs=20, eps=1e-8):
    n, d = X.shape
    w = np.zeros(d)
    G = np.zeros(d)

    history = []

    for epoch in range(epochs):
        for _ in range(n):
            i = np.random.randint(0, n)

            g = grad_i(w, X[i], y[i])

            G += g**2

            adjusted_lr = lr / (np.sqrt(G) + eps)

            w -= adjusted_lr * g

        history.append(np.linalg.norm(full_gradient(w, X, y)))

    return w, history

# %%
w_adagrad, hist_adagrad = adagrad(X, y, lr=0.1, epochs=30)

# %%
plt.plot(hist_adagrad)
plt.yscale("log")
plt.xlabel("Epoch")
plt.ylabel("Gradient Norm")
plt.title("AdaGrad Convergence")
plt.show()
